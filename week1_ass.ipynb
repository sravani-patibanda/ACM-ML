# %% [markdown]
# <a href="https://colab.research.google.com/github/sravani-patibanda/ACM-ML/blob/master/week1_ass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-a5a8261f-43ce-436b-8ada-d08c5ec48150" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a5a8261f-43ce-436b-8ada-d08c5ec48150">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving udemy_courses.csv to udemy_courses.csv

# %%
data=pd.read_csv("udemy_courses.csv")
data.head()
# Out:
#    course_id  ...           subject
# 0    1070968  ...  Business Finance
# 1    1113822  ...  Business Finance
# 2    1006314  ...  Business Finance
# 3    1210588  ...  Business Finance
# 4    1011058  ...  Business Finance
#
# [5 rows x 12 columns]

# %%
data.tail()
# Out:
#       course_id  ...          subject
# 3673     775618  ...  Web Development
# 3674    1088178  ...  Web Development
# 3675     635248  ...  Web Development
# 3676     905096  ...  Web Development
# 3677     297602  ...  Web Development
#
# [5 rows x 12 columns]

# %%
data.shape
# Out:
# (3678, 12)

# %%
data.describe()
# Out:
#           course_id        price  ...  num_lectures  content_duration
# count  3.678000e+03  3678.000000  ...   3678.000000       3678.000000
# mean   6.759720e+05    66.049483  ...     40.108755          4.094517
# std    3.432732e+05    61.005755  ...     50.383346          6.053840
# min    8.324000e+03     0.000000  ...      0.000000          0.000000
# 25%    4.076925e+05    20.000000  ...     15.000000          1.000000
# 50%    6.879170e+05    45.000000  ...     25.000000          2.000000
# 75%    9.613555e+05    95.000000  ...     45.750000          4.500000
# max    1.282064e+06   200.000000  ...    779.000000         78.500000
#
# [8 rows x 6 columns]

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data.nunique()
# Out:
# course_id              3672
# course_title           3663
# url                    3672
# is_paid                   2
# price                    38
# num_subscribers        2197
# num_reviews             511
# num_lectures            229
# level                     4
# content_duration        105
# published_timestamp    3672
# subject                   4
# dtype: int64

# %%
data['num_subscribers'].unique()
# Out:
# array([2147, 2792, 2174, ...,  555,  436,  901])

# %%
#cleaning the data
data.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
sns.set(style="darkgrid")
a1 = sns.countplot(x="is_paid", data=data,palette="Pastel2")

# %%
data['price'].plot.hist()

# %%
sns.distplot(data['num_lectures']);

# %%
data.plot.scatter(x='price',y='num_subscribers')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
sns.countplot(y="level", data=data, palette="Set3")

# %%
sns.catplot(x="level", y="num_reviews", jitter=False, data=data);

# %%
sns.catplot(x="level", y="price", kind="box", data=data);

# %%
plt.scatter(x="content_duration", y="num_lectures",data=data);
plt.ylabel('content_duration')
plt.xlabel('num_lectures')
plt.show()

# %%
sns.catplot(x="num_subscribers", y="level", kind="point", data=data);

# %%
#realtionship analysis
corelation=data.corr()
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)

# %%
data.plot.bar(stacked=True)
plt.legend(title='Business Finance')
plt.show()

data.plot.bar(stacked=True)
plt.legend(title='Graphic Design')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py:125: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
